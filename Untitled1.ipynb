# %% [markdown]
# Mount Google Drive:

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Github/
# Out:
# Mounted at /content/drive

# %%
# !git clone https://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@github.com/tobnie/gaze_predictor_nn.git
# Out:
# Cloning into 'gaze_predictor_nn'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 14 (delta 2), reused 14 (delta 2), pack-reused 0
# Unpacking objects: 100% (14/14), done.

# %%
# %cd gaze_predictor_nn
# %ls -a
# Out:
# [Errno 2] No such file or directory: 'gaze_predictor_nn'
# /content/gaze_predictor_nn
# ./  ../  architectures/  data/  .git/

# %%
# !git config --global user.email "niehues.tobias@gmail.com"
# !git config --global user.name "tobnie"

# !git add .
# !git commit -m "Colab Notebook"
# !git status
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
